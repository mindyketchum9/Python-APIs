# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559707 sha256=0192289556d18699867c6aaeef058bca327cf1478f84d64115349b4b78bcdd75
#   Stored in directory: c:\users\mindy\appdata\local\pip\cache\wheels\eb\07\14\1c448d9fabf3aceac66270933ecae15693974a1b7f91266841
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns
import requests
import time
import urllib
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Build URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" 
wkey = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
appid = wkey
settings = {"units": "imperial", "appid": wkey}
url = f"{url}appid={wkey}&units={units}"

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial'

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_latitute = city_weather["coord"]["lat"]
        city_longitude = city_weather["coord"]["lon"]
        city_max_temperature = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_latitute, 
                          "Lng": city_longitude, 
                          "Max Temp": city_max_temperature,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=barrow
# Processing Record 2 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=atuona
# Processing Record 3 of Set 1 | conde
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=conde
# Processing Record 4 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rikitea
# Processing Record 5 of Set 1 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hambantota
# Processing Record 6 of Set 1 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=qasigiannguit
# Processing Record 7 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hilo
# Processing Record 8 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tasiilaq
# Processing Record 9 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=attawapiskat
# City not found...
# Processing Record 10 of Set 1 | boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=boa%20vista
# Processing Record 11 of Set 1 | ondo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ondo
# Processing Record 12 of Set 1 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=asau
# Processing Record 13 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=puerto%20ayora
# Processing Record 14 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=provideniya
# Processing Record 15 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hermanus
# Processing Record 16 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hobart
# Processing Record 17 of Set 1 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=belaya%20gora
# Processing Record 18 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=khatanga
# Processing Record 19 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=codrington
# Processing Record 20 of Set 1 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=xai-xai
# Processing Record 21 of Set 1 | buala
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=buala
# Processing Record 22 of Set 1 | saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=saleaula
# City not found...
# Processing Record 23 of Set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=clyde%20river
# Processing Record 24 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mahebourg
# Processing Record 25 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nanortalik
# Processing Record 26 of Set 1 | shibukawa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=shibukawa
# Processing Record 27 of Set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tsihombe
# City not found...
# Processing Record 28 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=belushya%20guba
# City not found...
# Processing Record 29 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=albany
# Processing Record 30 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=klaksvik
# Processing Record 31 of Set 1 | kyra
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kyra
# Processing Record 32 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ushuaia
# Processing Record 33 of Set 1 | linchuan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=linchuan
# City not found...
# Processing Record 34 of Set 1 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=diego%20de%20almagro
# Processing Record 35 of Set 1 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kununurra
# Processing Record 36 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=punta%20arenas
# Processing Record 37 of Set 1 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=yerbogachen
# Processing Record 38 of Set 1 | menongue
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=menongue
# Processing Record 39 of Set 1 | merrill
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=merrill
# Processing Record 40 of Set 1 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=guerrero%20negro
# Processing Record 41 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=taolanaro
# City not found...
# Processing Record 42 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=busselton
# Processing Record 43 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vila%20franca%20do%20campo
# Processing Record 44 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bredasdorp
# Processing Record 45 of Set 1 | khasan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=khasan
# Processing Record 46 of Set 1 | playa del carmen
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=playa%20del%20carmen
# Processing Record 47 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kodiak
# Processing Record 48 of Set 1 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kangaatsiaq
# Processing Record 49 of Set 1 | dajal
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dajal
# Processing Record 50 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jamestown
# Processing Record 0 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nikolskoye
# Processing Record 1 of Set 2 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=fortuna
# Processing Record 2 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tuktoyaktuk
# Processing Record 3 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=chuy
# Processing Record 4 of Set 2 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=novyy%20urengoy
# Processing Record 5 of Set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=saldanha
# Processing Record 6 of Set 2 | capaci
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=capaci
# Processing Record 7 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=severo-kurilsk
# Processing Record 8 of Set 2 | vung tau
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vung%20tau
# Processing Record 9 of Set 2 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20hedland
# Processing Record 10 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lebu
# Processing Record 11 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bluff
# Processing Record 12 of Set 2 | kurchum
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kurchum
# Processing Record 13 of Set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=marcona
# City not found...
# Processing Record 14 of Set 2 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=samalaeulu
# City not found...
# Processing Record 15 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=butaritari
# Processing Record 16 of Set 2 | taklisah
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=taklisah
# Processing Record 17 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=thompson
# Processing Record 18 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vaini
# Processing Record 19 of Set 2 | biak
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=biak
# Processing Record 20 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=qaanaaq
# Processing Record 21 of Set 2 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=turukhansk
# Processing Record 22 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=yellowknife
# Processing Record 23 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=saint-philippe
# Processing Record 24 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=castro
# Processing Record 25 of Set 2 | jacqueville
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jacqueville
# Processing Record 26 of Set 2 | tingrela
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tingrela
# City not found...
# Processing Record 27 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mount%20gambier
# Processing Record 28 of Set 2 | oudtshoorn
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=oudtshoorn
# Processing Record 29 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mataura
# Processing Record 30 of Set 2 | christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=christchurch
# Processing Record 31 of Set 2 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=palmer
# Processing Record 32 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20alfred
# Processing Record 33 of Set 2 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=aksu
# Processing Record 34 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kapaa
# Processing Record 35 of Set 2 | vanavara
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vanavara
# Processing Record 36 of Set 2 | dormidontovka
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dormidontovka
# Processing Record 37 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mar%20del%20plata
# Processing Record 38 of Set 2 | disna
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=disna
# Processing Record 39 of Set 2 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hualmay
# Processing Record 40 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ponta%20do%20sol
# Processing Record 41 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hasaki
# Processing Record 42 of Set 2 | kpandae
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kpandae
# Processing Record 43 of Set 2 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=puerto%20escondido
# Processing Record 44 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bathsheba
# Processing Record 45 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=upernavik
# Processing Record 46 of Set 2 | correntina
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=correntina
# Processing Record 47 of Set 2 | teya
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=teya
# Processing Record 48 of Set 2 | laramie
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=laramie
# Processing Record 49 of Set 2 | ramtek
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ramtek
# Processing Record 0 of Set 3 | luganville
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=luganville
# Processing Record 1 of Set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vaitupu
# City not found...
# Processing Record 2 of Set 3 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=east%20london
# Processing Record 3 of Set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lata
# Processing Record 4 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=carnarvon
# Processing Record 5 of Set 3 | mae sai
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mae%20sai
# Processing Record 6 of Set 3 | banswada
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=banswada
# Processing Record 7 of Set 3 | anito
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=anito
# Processing Record 8 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sitka
# Processing Record 9 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=new%20norfolk
# Processing Record 10 of Set 3 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=thunder%20bay
# Processing Record 11 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bambous%20virieux
# Processing Record 12 of Set 3 | high level
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=high%20level
# Processing Record 13 of Set 3 | eskasem
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=eskasem
# City not found...
# Processing Record 14 of Set 3 | lagos
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lagos
# Processing Record 15 of Set 3 | storslett
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=storslett
# Processing Record 16 of Set 3 | san javier
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=san%20javier
# Processing Record 17 of Set 3 | tiarei
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tiarei
# Processing Record 18 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=georgetown
# Processing Record 19 of Set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=isangel
# Processing Record 20 of Set 3 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=chapais
# Processing Record 21 of Set 3 | tibiri
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tibiri
# Processing Record 22 of Set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=illoqqortoormiut
# City not found...
# Processing Record 23 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mys%20shmidta
# City not found...
# Processing Record 24 of Set 3 | sakakah
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sakakah
# Processing Record 25 of Set 3 | vancouver
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vancouver
# Processing Record 26 of Set 3 | palotina
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=palotina
# Processing Record 27 of Set 3 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sovetskiy
# Processing Record 28 of Set 3 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=seoul
# Processing Record 29 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=talnakh
# Processing Record 30 of Set 3 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vao
# Processing Record 31 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=norman%20wells
# Processing Record 32 of Set 3 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dunedin
# Processing Record 33 of Set 3 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=najran
# Processing Record 34 of Set 3 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20moresby
# Processing Record 35 of Set 3 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kahului
# Processing Record 36 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bethel
# Processing Record 37 of Set 3 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=marawi
# Processing Record 38 of Set 3 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=faya
# Processing Record 39 of Set 3 | ondorhaan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ondorhaan
# City not found...
# Processing Record 40 of Set 3 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=avera
# Processing Record 41 of Set 3 | skara
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=skara
# Processing Record 42 of Set 3 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=flin%20flon
# Processing Record 43 of Set 3 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=amderma
# City not found...
# Processing Record 44 of Set 3 | tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tessalit
# Processing Record 45 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20elizabeth
# Processing Record 46 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=victoria
# Processing Record 47 of Set 3 | karaul
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=karaul
# City not found...
# Processing Record 48 of Set 3 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tual
# Processing Record 49 of Set 3 | erdemli
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=erdemli
# Processing Record 0 of Set 4 | labrea
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=labrea
# Processing Record 1 of Set 4 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cape%20town
# Processing Record 2 of Set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hofn
# Processing Record 3 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hithadhoo
# Processing Record 4 of Set 4 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dikson
# Processing Record 5 of Set 4 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hamilton
# Processing Record 6 of Set 4 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=yulara
# Processing Record 7 of Set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=constitucion
# Processing Record 8 of Set 4 | santa isabel
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=santa%20isabel
# Processing Record 9 of Set 4 | kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kamenka
# Processing Record 10 of Set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20lincoln
# Processing Record 11 of Set 4 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jalu
# Processing Record 12 of Set 4 | filingue
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=filingue
# Processing Record 13 of Set 4 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nizhneyansk
# City not found...
# Processing Record 14 of Set 4 | nador
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nador
# Processing Record 15 of Set 4 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=derzhavinsk
# Processing Record 16 of Set 4 | chuzhou
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=chuzhou
# Processing Record 17 of Set 4 | wadi maliz
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=wadi%20maliz
# Processing Record 18 of Set 4 | lagunas
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lagunas
# Processing Record 19 of Set 4 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=havre-saint-pierre
# Processing Record 20 of Set 4 | liku
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=liku
# Processing Record 21 of Set 4 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sur
# Processing Record 22 of Set 4 | douentza
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=douentza
# Processing Record 23 of Set 4 | nivala
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nivala
# Processing Record 24 of Set 4 | podbelsk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=podbelsk
# City not found...
# Processing Record 25 of Set 4 | mwinilunga
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mwinilunga
# Processing Record 26 of Set 4 | banjar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=banjar
# Processing Record 27 of Set 4 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=pisco
# Processing Record 28 of Set 4 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=pevek
# Processing Record 29 of Set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=chokurdakh
# Processing Record 30 of Set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tuatapere
# Processing Record 31 of Set 4 | trairi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=trairi
# Processing Record 32 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nouadhibou
# Processing Record 33 of Set 4 | whithorn
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=whithorn
# Processing Record 34 of Set 4 | andrelandia
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=andrelandia
# Processing Record 35 of Set 4 | bocaranga
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bocaranga
# City not found...
# Processing Record 36 of Set 4 | astrakhan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=astrakhan
# Processing Record 37 of Set 4 | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=aklavik
# Processing Record 38 of Set 4 | albanel
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=albanel
# Processing Record 39 of Set 4 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=namibe
# Processing Record 40 of Set 4 | homa bay
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=homa%20bay
# Processing Record 41 of Set 4 | riberalta
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=riberalta
# Processing Record 42 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=katsuura
# Processing Record 43 of Set 4 | denpasar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=denpasar
# Processing Record 44 of Set 4 | bakaly
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bakaly
# Processing Record 45 of Set 4 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=geraldton
# Processing Record 46 of Set 4 | marienburg
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=marienburg
# Processing Record 47 of Set 4 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nizhniy%20kuranakh
# Processing Record 48 of Set 4 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sobolevo
# Processing Record 49 of Set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cherskiy
# Processing Record 0 of Set 5 | skagastrond
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=skagastrond
# City not found...
# Processing Record 1 of Set 5 | jabiru
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jabiru
# City not found...
# Processing Record 2 of Set 5 | baykit
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=baykit
# Processing Record 3 of Set 5 | fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=fort-shevchenko
# Processing Record 4 of Set 5 | amapa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=amapa
# Processing Record 5 of Set 5 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=los%20llanos%20de%20aridane
# Processing Record 6 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sao%20filipe
# Processing Record 7 of Set 5 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=abu%20dhabi
# Processing Record 8 of Set 5 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=iralaya
# Processing Record 9 of Set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ribeira%20grande
# Processing Record 10 of Set 5 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mandalgovi
# Processing Record 11 of Set 5 | pictou
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=pictou
# Processing Record 12 of Set 5 | shahapur
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=shahapur
# Processing Record 13 of Set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cidreira
# Processing Record 14 of Set 5 | ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ondjiva
# Processing Record 15 of Set 5 | rosarito
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rosarito
# Processing Record 16 of Set 5 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=san%20quintin
# Processing Record 17 of Set 5 | palencia
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=palencia
# Processing Record 18 of Set 5 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rawannawi
# City not found...
# Processing Record 19 of Set 5 | visnes
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=visnes
# Processing Record 20 of Set 5 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kaitangata
# Processing Record 21 of Set 5 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=umm%20kaddadah
# Processing Record 22 of Set 5 | antalaha
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=antalaha
# Processing Record 23 of Set 5 | teseney
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=teseney
# Processing Record 24 of Set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cap%20malheureux
# Processing Record 25 of Set 5 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=luderitz
# Processing Record 26 of Set 5 | itamarandiba
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=itamarandiba
# Processing Record 27 of Set 5 | ust-kan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ust-kan
# Processing Record 28 of Set 5 | vilcun
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vilcun
# Processing Record 29 of Set 5 | shache
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=shache
# Processing Record 30 of Set 5 | asyut
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=asyut
# Processing Record 31 of Set 5 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=arlit
# Processing Record 32 of Set 5 | opportunity
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=opportunity
# Processing Record 33 of Set 5 | gizo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=gizo
# Processing Record 34 of Set 5 | cedar city
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cedar%20city
# Processing Record 35 of Set 5 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=atar
# Processing Record 36 of Set 5 | hirara
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=hirara
# Processing Record 37 of Set 5 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=grand%20river%20south%20east
# City not found...
# Processing Record 38 of Set 5 | bara
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bara
# Processing Record 39 of Set 5 | stutterheim
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=stutterheim
# Processing Record 40 of Set 5 | bosaso
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bosaso
# Processing Record 41 of Set 5 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lagoa
# Processing Record 42 of Set 5 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=beyneu
# Processing Record 43 of Set 5 | rochester
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rochester
# Processing Record 44 of Set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lorengau
# Processing Record 45 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tiksi
# Processing Record 46 of Set 5 | horsham
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=horsham
# Processing Record 47 of Set 5 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tiznit
# Processing Record 48 of Set 5 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tilichiki
# Processing Record 49 of Set 5 | kuusamo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kuusamo
# Processing Record 0 of Set 6 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=samarai
# Processing Record 1 of Set 6 | cochrane
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cochrane
# Processing Record 2 of Set 6 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ilulissat
# Processing Record 3 of Set 6 | goderich
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=goderich
# Processing Record 4 of Set 6 | carauari
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=carauari
# Processing Record 5 of Set 6 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kruisfontein
# Processing Record 6 of Set 6 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=barentsburg
# City not found...
# Processing Record 7 of Set 6 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20blair
# Processing Record 8 of Set 6 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=saint-augustin
# Processing Record 9 of Set 6 | grootfontein
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=grootfontein
# Processing Record 10 of Set 6 | inuvik
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=inuvik
# Processing Record 11 of Set 6 | pionki
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=pionki
# Processing Record 12 of Set 6 | boueni
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=boueni
# Processing Record 13 of Set 6 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=presidencia%20roque%20saenz%20pena
# Processing Record 14 of Set 6 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rawson
# Processing Record 15 of Set 6 | russell
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=russell
# Processing Record 16 of Set 6 | aripuana
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=aripuana
# Processing Record 17 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=leningradskiy
# Processing Record 18 of Set 6 | macaboboni
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=macaboboni
# City not found...
# Processing Record 19 of Set 6 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=prince%20rupert
# Processing Record 20 of Set 6 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=louisbourg
# City not found...
# Processing Record 21 of Set 6 | bondo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bondo
# Processing Record 22 of Set 6 | ocos
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ocos
# Processing Record 23 of Set 6 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lompoc
# Processing Record 24 of Set 6 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bundaberg
# Processing Record 25 of Set 6 | ambulu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ambulu
# Processing Record 26 of Set 6 | baiyin
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=baiyin
# Processing Record 27 of Set 6 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=yar-sale
# Processing Record 28 of Set 6 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=arraial%20do%20cabo
# Processing Record 29 of Set 6 | shakhrinau
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=shakhrinau
# City not found...
# Processing Record 30 of Set 6 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=saint-pierre
# Processing Record 31 of Set 6 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=avarua
# Processing Record 32 of Set 6 | nizwa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nizwa
# Processing Record 33 of Set 6 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=portland
# Processing Record 34 of Set 6 | sao joao de pirabas
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sao%20joao%20de%20pirabas
# Processing Record 35 of Set 6 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=samusu
# City not found...
# Processing Record 36 of Set 6 | port shepstone
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=port%20shepstone
# Processing Record 37 of Set 6 | ballina
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ballina
# Processing Record 38 of Set 6 | ak-dovurak
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ak-dovurak
# Processing Record 39 of Set 6 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bac%20lieu
# Processing Record 40 of Set 6 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vilhena
# Processing Record 41 of Set 6 | kolondieba
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kolondieba
# Processing Record 42 of Set 6 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kamenskoye
# City not found...
# Processing Record 43 of Set 6 | maxineni
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=maxineni
# Processing Record 44 of Set 6 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=alofi
# Processing Record 45 of Set 6 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=caravelas
# Processing Record 46 of Set 6 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=raudeberg
# Processing Record 47 of Set 6 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=torbay
# Processing Record 48 of Set 6 | chabahar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=chabahar
# Processing Record 49 of Set 6 | haibowan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=haibowan
# City not found...
# Processing Record 0 of Set 7 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vardo
# Processing Record 1 of Set 7 | eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=eyrarbakki
# Processing Record 2 of Set 7 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=nemuro
# Processing Record 3 of Set 7 | karakendzha
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=karakendzha
# City not found...
# Processing Record 4 of Set 7 | awbari
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=awbari
# Processing Record 5 of Set 7 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=camacha
# Processing Record 6 of Set 7 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=faanui
# ...
# Processing Record 45 of Set 10 | juneau
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=juneau
# Processing Record 46 of Set 10 | mountain home
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mountain%20home
# Processing Record 47 of Set 10 | verkhniy fiagdon
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=verkhniy%20fiagdon
# Processing Record 48 of Set 10 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=bandarbeyla
# Processing Record 49 of Set 10 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=te%20anau
# Processing Record 0 of Set 11 | jardim
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jardim
# Processing Record 1 of Set 11 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ust-kuyga
# Processing Record 2 of Set 11 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=maniitsoq
# Processing Record 3 of Set 11 | les escoumins
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=les%20escoumins
# Processing Record 4 of Set 11 | dinsor
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dinsor
# City not found...
# Processing Record 5 of Set 11 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tazovskiy
# Processing Record 6 of Set 11 | tezu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tezu
# Processing Record 7 of Set 11 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mayo
# Processing Record 8 of Set 11 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kazalinsk
# City not found...
# Processing Record 9 of Set 11 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=puerto%20del%20rosario
# Processing Record 10 of Set 11 | lodja
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=lodja
# Processing Record 11 of Set 11 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rio%20grande
# Processing Record 12 of Set 11 | latung
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=latung
# Processing Record 13 of Set 11 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=batticaloa
# Processing Record 14 of Set 11 | grand-lahou
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=grand-lahou
# Processing Record 15 of Set 11 | shar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=shar
# Processing Record 16 of Set 11 | azacualpa
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=azacualpa
# Processing Record 17 of Set 11 | shumskiy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=shumskiy
# Processing Record 18 of Set 11 | jaguey grande
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jaguey%20grande
# Processing Record 19 of Set 11 | manggar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=manggar
# Processing Record 20 of Set 11 | uwayl
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=uwayl
# City not found...
# Processing Record 21 of Set 11 | pudozh
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=pudozh
# Processing Record 22 of Set 11 | tuggurt
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=tuggurt
# City not found...
# Processing Record 23 of Set 11 | butterworth
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=butterworth
# Processing Record 24 of Set 11 | braintree
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=braintree
# Processing Record 25 of Set 11 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=walvis%20bay
# Processing Record 26 of Set 11 | varnavino
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=varnavino
# Processing Record 27 of Set 11 | darlowo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=darlowo
# Processing Record 28 of Set 11 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=keti%20bandar
# Processing Record 29 of Set 11 | erdenet
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=erdenet
# Processing Record 30 of Set 11 | rawdon
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rawdon
# Processing Record 31 of Set 11 | kuche
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kuche
# City not found...
# Processing Record 32 of Set 11 | paita
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=paita
# Processing Record 33 of Set 11 | moron
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=moron
# Processing Record 34 of Set 11 | ulcinj
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ulcinj
# Processing Record 35 of Set 11 | khoy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=khoy
# Processing Record 36 of Set 11 | turayf
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=turayf
# Processing Record 37 of Set 11 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kloulklubed
# Processing Record 38 of Set 11 | kudymkar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kudymkar
# Processing Record 39 of Set 11 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=beloha
# Processing Record 40 of Set 11 | ilo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ilo
# Processing Record 41 of Set 11 | muli
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=muli
# Processing Record 42 of Set 11 | ericeira
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ericeira
# Processing Record 43 of Set 11 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=alta%20floresta
# Processing Record 44 of Set 11 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=okhotsk
# Processing Record 45 of Set 11 | mongar
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=mongar
# Processing Record 46 of Set 11 | safwah
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=safwah
# City not found...
# Processing Record 47 of Set 11 | alihe
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=alihe
# Processing Record 48 of Set 11 | caxito
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=caxito
# Processing Record 49 of Set 11 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=fevralsk
# City not found...
# Processing Record 0 of Set 12 | elat
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=elat
# Processing Record 1 of Set 12 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=olafsvik
# Processing Record 2 of Set 12 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=deputatskiy
# Processing Record 3 of Set 12 | babanusah
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=babanusah
# City not found...
# Processing Record 4 of Set 12 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=saint-joseph
# Processing Record 5 of Set 12 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=aswan
# Processing Record 6 of Set 12 | zeya
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=zeya
# Processing Record 7 of Set 12 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=paamiut
# Processing Record 8 of Set 12 | dunda
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dunda
# Processing Record 9 of Set 12 | muzhi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=muzhi
# Processing Record 10 of Set 12 | kandi
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kandi
# Processing Record 11 of Set 12 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ruatoria
# City not found...
# Processing Record 12 of Set 12 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=muravlenko
# Processing Record 13 of Set 12 | okato
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=okato
# Processing Record 14 of Set 12 | kozluk
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kozluk
# Processing Record 15 of Set 12 | humaita
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=humaita
# Processing Record 16 of Set 12 | vega de alatorre
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vega%20de%20alatorre
# Processing Record 17 of Set 12 | montijo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=montijo
# Processing Record 18 of Set 12 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=namatanai
# Processing Record 19 of Set 12 | umm durman
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=umm%20durman
# City not found...
# Processing Record 20 of Set 12 | khorol
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=khorol
# Processing Record 21 of Set 12 | kamachumu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kamachumu
# Processing Record 22 of Set 12 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=dongsheng
# Processing Record 23 of Set 12 | otjiwarongo
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=otjiwarongo
# Processing Record 24 of Set 12 | vieux-habitants
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vieux-habitants
# Processing Record 25 of Set 12 | williams lake
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=williams%20lake
# Processing Record 26 of Set 12 | sattahip
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sattahip
# Processing Record 27 of Set 12 | kathmandu
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=kathmandu
# Processing Record 28 of Set 12 | jinka
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=jinka
# Processing Record 29 of Set 12 | casma
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=casma
# Processing Record 30 of Set 12 | peru
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=peru
# Processing Record 31 of Set 12 | vagur
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=vagur
# Processing Record 32 of Set 12 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=antofagasta
# Processing Record 33 of Set 12 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=grand%20gaube
# Processing Record 34 of Set 12 | sumbe
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=sumbe
# Processing Record 35 of Set 12 | ruidoso
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ruidoso
# Processing Record 36 of Set 12 | rameswaram
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=rameswaram
# Processing Record 37 of Set 12 | cobija
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=cobija
# Processing Record 38 of Set 12 | manicore
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=manicore
# Processing Record 39 of Set 12 | van
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=van
# Processing Record 40 of Set 12 | murakami
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=murakami
# Processing Record 41 of Set 12 | catamarca
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=catamarca
# Processing Record 42 of Set 12 | uhlove
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=uhlove
# Processing Record 43 of Set 12 | warri
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=warri
# Processing Record 44 of Set 12 | fuzhou
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=fuzhou
# Processing Record 45 of Set 12 | artyom
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=artyom
# Processing Record 46 of Set 12 | ajdabiya
# http://api.openweathermap.org/data/2.5/weather?appid=5b6dc96509919ee7bd36f35c7e82e7cd&units=imperial&q=ajdabiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Export the City_Data into a csv
city_data_pd.to_csv("WeatherPy.csv",encoding="utf-8",index=False)


# Show Record Count
city_data_pd.count()
# Out:
# City          545
# Lat           545
# Lng           545
# Max Temp      545
# Humidity      545
# Cloudiness    545
# Wind Speed    545
# Country       545
# Date          545
# dtype: int64

# %%
city_data_pd = pd.read_csv("WeatherPy.csv")

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      barrow  71.29 -156.79     39.20        86          90       12.75
# 1      atuona  -9.80 -139.03     78.96        79          38       25.99
# 2       conde  -7.26  -34.91     73.40        94           0        6.93
# 3     rikitea -23.12 -134.97     69.46        82          27       17.07
# 4  hambantota   6.12   81.12     82.40        83          40        6.93
#
#   Country        Date
# 0      US  1598843119
# 1      PF  1598843113
# 2      BR  1598843519
# 3      PF  1598843107
# 4      LK  1598843139

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  545.000000  545.000000  545.000000  545.000000  545.000000  545.000000
# mean    19.786440   18.268550   65.960771   72.592661   47.286239    7.807450
# std     33.567298   88.487285   14.428230   19.129857   40.289790    5.307638
# min    -54.800000 -175.200000   28.630000    1.000000    0.000000    0.470000
# 25%     -8.650000  -60.630000   55.000000   62.000000    1.000000    3.870000
# 50%     22.890000   20.230000   67.420000   77.000000   40.000000    6.710000
# 75%     48.570000   92.750000   78.010000   87.000000   90.000000   10.290000
# max     78.220000  179.320000   96.800000  100.000000  100.000000   30.940000
#
#                Date
# count  5.450000e+02
# mean   1.598843e+09
# std    2.274171e+02
# min    1.598843e+09
# 25%    1.598843e+09
# 50%    1.598844e+09
# 75%    1.598844e+09
# max    1.598844e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_pd["Lat"], city_data_pd["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure


# Show plot
plt.show()

# %%
# In the city latitude vs max temperature, we can see that areas further away from the equator (-60 are 80) are much colder 
# and places that are closer to the equator (0), are generally warmer.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_pd["Lat"], city_data_pd["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %%
# It does not look like there is a correlation between humidity and latitude. Humidity is generally based on location to water.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_pd["Lat"], city_data_pd["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the gragh


# Show plot
plt.show()

# %%
# It does not appear there is a correlation between latitude and cloudiness. Weather is dependent upon many factors.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data_pd["Lat"], city_data_pd["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure


# Show plot
plt.show()

# %%
# It does not appear there is a correlation between latitude and wind speed. 
# Wind speed is based on a variety of factors including weather and geography.

# %% [markdown]
# ## Linear Regression

# %%
df_NorthernHem = city_data_pd.loc[city_data_pd["Lat"] > 0]
df_SouthernHem = city_data_pd.loc[city_data_pd["Lat"] < 0]

# %%
x_values = df_NorthernHem["Lat"]
y_values = df_NorthernHem["Max Temp"]

# %%
def regressplot(x_values, y_values):

    # Perform a linear regression on temperature vs. latitude
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    print(regress_values)

    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

    # Build a scatter plot for each data type
    plt.scatter(x_values, y_values , marker="o", s=10)
    plt.plot(x_values,regress_values,"r-")

    # Incorporate the other graph properties

    plt.xlabel("Latitude")
    plt.grid(True)
    plt.annotate(line_eq,(20,15),fontsize=15,color="red")


    
    # Print r value
    print(f"The r-value is: {rvalue**2}")

    # Save the figure


    # Show plot
    plt.show()

# %%
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")

regressplot(x_values, y_values)
# Out:
# 0      47.843475
# 4      85.489254
# 5      49.270283
# 6      77.627369
# 7      51.124555
#          ...
# 540    63.134004
# 541    85.835847
# 542    73.970812
# 543    65.646803
# 544    71.255834
# Name: Lat, Length: 370, dtype: float64
# The r-value is: 0.6631338107300853

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = df_SouthernHem["Lat"]
y_values = df_SouthernHem["Max Temp"]

# %%
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")

regressplot(x_values, y_values)
# Out:
# 1      74.367787
# 2      76.417787
# 3      63.617390
# 11     81.679993
# 13     54.497309
#          ...
# 531    66.127430
# 532    73.229794
# 535    73.375070
# 536    77.588063
# 539    59.299476
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.5179371276334398

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = df_SouthernHem["Lat"]
y_values = df_SouthernHem["Max Temp"]

# %%
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")

regressplot(x_values, y_values)
# Out:
# 1      74.367787
# 2      76.417787
# 3      63.617390
# 11     81.679993
# 13     54.497309
#          ...
# 531    66.127430
# 532    73.229794
# 535    73.375070
# 536    77.588063
# 539    59.299476
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.5179371276334398

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = df_NorthernHem["Lat"]
y_values = df_NorthernHem["Humidity"]

# %%
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")

regressplot(x_values, y_values)
# Out:
# 1      71.976144
# 2      72.391436
# 3      69.798310
# 11     73.457463
# 13     67.950748
#          ...
# 531    70.306798
# 532    71.745607
# 535    71.775037
# 536    72.628513
# 539    68.923579
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.014859238841164014

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = df_SouthernHem["Lat"]
y_values = df_SouthernHem["Humidity"]

# %%
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")

regressplot(x_values, y_values)
# Out:
# 1      71.976144
# 2      72.391436
# 3      69.798310
# 11     73.457463
# 13     67.950748
#          ...
# 531    70.306798
# 532    71.745607
# 535    71.775037
# 536    72.628513
# 539    68.923579
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.014859238841164014

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = df_NorthernHem["Lat"]
y_values = df_NorthernHem["Cloudiness"]

# %%
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")

regressplot(x_values, y_values)
# Out:
# 0      51.177521
# 4      47.785547
# 5      51.048962
# 6      48.493921
# 7      50.881888
#          ...
# 540    49.799808
# 541    47.754318
# 542    48.823386
# 543    49.573399
# 544    49.068012
# Name: Lat, Length: 370, dtype: float64
# The r-value is: 0.000652749347632978

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = df_SouthernHem["Lat"]
y_values = df_SouthernHem["Cloudiness"]

# %%
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")

regressplot(x_values, y_values)
# Out:
# 1      46.973037
# 2      47.942082
# 3      41.891273
# 11     50.429553
# 13     37.580167
#          ...
# 531    43.077781
# 532    46.435103
# 535    46.503775
# 536    48.495278
# 539    39.850174
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.01691477549608124

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = df_NorthernHem["Lat"]
y_values = df_NorthernHem["Wind Speed"]

# %%
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")

regressplot(x_values, y_values)
# Out:
# 1      46.973037
# 2      47.942082
# 3      41.891273
# 11     50.429553
# 13     37.580167
#          ...
# 531    43.077781
# 532    46.435103
# 535    46.503775
# 536    48.495278
# 539    39.850174
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.01691477549608124

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = df_SouthernHem["Lat"]
y_values = df_SouthernHem["Wind Speed"]

# %%
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")

regressplot(x_values, y_values)
# Out:
# 1      8.008997
# 2      7.884980
# 3      8.659353
# 11     7.566637
# 13     9.211082
#          ...
# 531    8.507506
# 532    8.077841
# 535    8.069052
# 536    7.814183
# 539    8.920570
# Name: Lat, Length: 175, dtype: float64
# The r-value is: 0.013088588753058851
